# %% [markdown]
# <a href="https://colab.research.google.com/github/kisomose/machine_learning_model/blob/main/ML_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# define our data
x = np.array([-1,0,1,2,3,4,5], dtype=int)
y = np.array([-2,1,4,7,10,13,16], dtype=int)

# %%
# define model
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
# Compile our model for optimizing our data to see how accurate it is
# sdg = stochastic gradient descent
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# training the model
# epochs how many iterations you want it to go through i.e., how long to train the model
model.fit(x,y, epochs= 700)
# Out:
# Epoch 1/700
# 1/1 [==============================] - 0s 462ms/step - loss: 31.9067
# Epoch 2/700
# 1/1 [==============================] - 0s 10ms/step - loss: 21.9850
# Epoch 3/700
# 1/1 [==============================] - 0s 6ms/step - loss: 15.1596
# Epoch 4/700
# 1/1 [==============================] - 0s 7ms/step - loss: 10.4639
# Epoch 5/700
# 1/1 [==============================] - 0s 5ms/step - loss: 7.2332
# Epoch 6/700
# 1/1 [==============================] - 0s 5ms/step - loss: 5.0103
# Epoch 7/700
# 1/1 [==============================] - 0s 5ms/step - loss: 3.4805
# Epoch 8/700
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4276
# Epoch 9/700
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7028
# Epoch 10/700
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2035
# Epoch 11/700
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8595
# Epoch 12/700
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6223
# ...

# %%
print(model.predict([34]))
# Out:
# [[103.005554]]

# %%
print(model.predict([103]))
# Out:
# [[310.01822]]

# %%
print(model.predict([500]))
# Out:
# [[1501.0911]]
